# %% [markdown]
# # Python Programming Exercise 1

# %% [markdown]
# 1. Write a python script to find the perimeter of a triangle. Get input from keyboard

# %% [markdown]
# Hint: perimeter = a + b + c
#
#     a = input(' give length of one side: ')
#
#     print('.....')

# %% [markdown]
# 2. Write a python script to find the area and perimeter of a circle. Get input from keyboard

# %% [markdown]
# 3. Write a python script to compute y. Get x from key board
#     y=(3x+4)/(2x-5)
