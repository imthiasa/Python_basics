# %% [markdown]
# # Python
# ## Simple Programs

# %%
a= 50
b =16
sum = a+b
print(sum)
# Out:
# 66

# %%
type(a)
# Out:
# int

# %%
a= 5
b=20
product = a*b
print(product)
# Out:
# 100

# %%
# Area of a Rectangle
length = 20
breadth = 4
area = length * breadth
print('Area =',area)
# Out:
# Area = 80

# %%
# Area of a Rectangle  float
length = 20.2
breadth = 4.1
type(length)
area = length*breadth
print('Area   :', area)
# Out:
# Area   : 82.82

# %%
name = 'John'
family_name = ' Parambath'
print(type(name))
full_name = name + family_name
print('full_name:', full_name)
# Out:
# full_name: John Parambath

# %% [raw]
# # Summary
# # Data types:  int, float, str
# # Built in Functions
# print(...)
# type(...)
